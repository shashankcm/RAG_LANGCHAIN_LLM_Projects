# %% [markdown]
# <a href="https://colab.research.google.com/github/shashankcm/RAG_LANGCHAIN_LLM_Projects/blob/main/simple_chatbot_with_gradio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip3 install langchain-openai
# !pip3 install gradio

# %%
from langchain_openai import ChatOpenAI
from google.colab import userdata

import os
import gradio as gr

api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key


model = ChatOpenAI(
    model='gpt-4o-mini',
    temperature=0.5,
    max_tokens=256,
)

def generate_response(prompt):
    response = model.invoke(prompt)
    return response.content

chatbot = gr.Interface(
    fn=generate_response,
    allow_flagging="never",
    inputs=gr.Textbox(label="Input", lines=2, placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Output", max_lines=100000000),
    title="Chatbot using openai and gradio",
    description="Ask any question and the chatbot will try to answer."
)

chatbot.launch(server_name="127.0.0.1", server_port= 7862)
